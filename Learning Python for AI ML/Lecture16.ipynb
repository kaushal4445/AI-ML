# %% [markdown]
# <a href="https://colab.research.google.com/github/kaushal4445/AI-ML/blob/main/Learning%20Python%20for%20AI%20ML/Lecture16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def fun(values):
  total =0

  for v in values:
    if v % 2 == 0:
      total += v

  return total

numbers = [5, 8, 12, 7, 10]
print(fun(numbers))
# Out:
# 30

# %%
student = {
    "Math" :80,
    "science" : 90,
    "english" : 85
}
count =0
for subject in student:
  if student[subject] >= 85:
    count += 1

print(count)
# Out:
# 2

# %%
student = {
    "Math" :80,
    "science" : 90,
    "english" : 85
}
sub =[]
for subject in student:
  if student[subject] >= 85:
    sub.append(subject)

print(sub)
# Out:
# ['science', 'english']

# %%
names = ["Rahul", "Amit", "Neha", "Riya"]
answer = ""

for name in names:
  if len(name) == 4:
    answer += name[-1]

print(answer)
# Out:
# taa

# %%
numbers = (10, 15, 20, 25)
result=()
for n in numbers:
  if n % 5 == 0:
    result += (n //5,)

print(result)
# Out:
# (2, 3, 4, 5)

# %%
# 28  minutes kita hai

# %%
numbers = (10, 15, 20, 25)
result=()
for n in numbers:
  if n % 5 == 0:
    result += (n //5,)

print(result)
# Out:
# (2, 3, 4, 5)

# %%
numbers = (10, 15, 20, 25)
result=(0)
for n in numbers:
  if n % 5 == 0:
    result += (n //5)

print(result)
# Out:
# 14

# %%
values = {2, 4, 6, 8}
total =0;
for value in values:
  total += value


print(total // len(values))
# Out:
# 5

# %%
type(values)
# Out:
# set

# %%
num = [3, 6, 9]
new = []
for n in num:
  new.append(n * n)

print(max(new))
print(new)
type(new)
# Out:
# 81
# [9, 36, 81]
# list

# %%
report = ("Kaushal", 22, 95)

name,  age , marks= report

if marks > 90:
  grade = "A"
else:
  grade = "B"

print(name, grade)
type(report)
# Out:
# Kaushal A
# tuple

# %%
fruits =["Apple", "Banana", "Mango"]

result = []
for fruit in fruits:
  if len(fruit) > 5:
    result.append(fruit.upper())

print(result)
# Out:
# ['BANANA']

# %%
data = {
    "A" : 5,
    "B" : 10,
    "C" :15
}
total = 0;
for key in data:
  total += data[key]

print(total / len(data))
# Out:
# 10.0

# %%
values = [2,4, 6, 8]
i =0
total = 0
while i< len(values):
  total += values[i]
  i += 2

print(total)
# Out:
# 8

# %%
text = "Mississippi"
count = {}
for ch in text:
  if ch not in count:
    count[ch]  = 1

  else:
    count[ch] += 1

print(count["s"])
# Out:
# 4

# %%
words = ["cat", "elephant", "dog", "tiger"]
longest = words[0]

for word in words:
  if len(word) > len(longest):
    longest = word

    print(longest)
# Out:
# elephant

# %%
bacha = {
    "rahul" : 90,
    "Amit" : 75,
    "Neha" : 95
}

highest_name : ""
highest_marks = 0

for name in bacha:
  if bacha[name] > highest_marks:
    highest_marks = bacha[name]
    highest_name = name

print(highest_name)
# Out:
# Neha

# %% [markdown]
# # SETS

# %%
sts= ["kaushal", "manoj", "krishna", "krishna"]
type(sts)
# Out:
# list

# %%
# write a code to only ro storre the unique occureness of the elemennets inthe list
s1 =[]
for st in sts:
  if st not in s1:
    s1.append(st)


print(s1)
# Out:
# ['kaushal', 'manoj', 'krishna']

# %% [markdown]
# # Set
# 1.store only the unique values
# 2. unordered
# 3.mutable(add/ remove elements)

# %%
num ={"name" : "kausahl"}
type(num)
# Out:
# dict

# %%
sets = {3, 6, 8,8,2, 1}
type(sets)
# Out:
# set

# %%
len(sets) # it counts duplicate once times
# Out:
# 5

# %%
s = {4, 3.2, "AJ", False}
type(s)
# Out:
# set

# %%
l =[]
t =()
d= {}
lap = set()
type(lap)
# Out:
# set

# %%
len(lap)
# Out:
# 0

# %%
nm = {4,5,7,2,4,8,1}
print(nm)  # it give already sort
# Out:
# {1, 2, 4, 5, 7, 8}

# %%
nm[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_6371/2196344789.py in <cell line: 0>()
# ----> 1 nm[0]
#
# TypeError: 'set' object is not subscriptable

# %%
for n in nm:
  print(n)
# Out:
# 1
# 2
# 4
# 5
# 7
# 8

# %%
nm.add(10)
print(nm)
# Out:
# {1, 2, 4, 5, 7, 8, 10}

# %%
nm.remove(4)
print(nm)
# Out:
# {1, 2, 5, 7, 8, 10}

# %%
nm.remove()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_6371/1849092294.py in <cell line: 0>()
# ----> 1 nm.remove()
#
# TypeError: set.remove() takes exactly one argument (0 given)

# %%
print(nm)
# Out:
# {1, 2, 5, 7, 8, 10}

# %%
item = nm.pop()
print(item) # pop randomly remove any elemenet
print(nm)
# Out:
# 5
# {7, 8, 10}

# %%
nm.clear()

# %%
print(nm)
# Out:
# set()

# %%
# union

A  = {1, 2, 3}
B = {3, 4, 5}
print(A | B)
# Out:
# {1, 2, 3, 4, 5}

# %%
# intersection
print(A & B)
# Out:
# {3}

# %%
# set difference
print(A -B)
# Out:
# {1, 2}

# %%
text= "banana"
letters  = set(text)
print(len(letters))
# Out:
# 3
