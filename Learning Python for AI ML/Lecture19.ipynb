# %% [markdown]
# <a href="https://colab.research.google.com/github/kaushal4445/AI-ML/blob/main/Learning%20Python%20for%20AI%20ML/Lecture19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # OOP using Python

# %%
# class ---> Blueprint
# Object --> specfic instance of that class

# %%
name = "Raj"
city = "Mumbai"
age = 20

# %%
# before n=manufacturing the car, the company would finalise the template

# features of the car that shouls be present in its blueprint:
# 1.Brand
# 2.Color
# 3.Price

# this is blueprint and the actual car ->object

# %%
class Student:
  pass   #placeholder --> do nothing

# %%
class Student:
  name = "Raj"
  city = "Mumbai"
  age = 20

# %%
s1 = Student()
print(s1.name, s1.city, s1.age)
# Out:
# Raj Mumbai 20

# %%
class Student:
   def __init__(self, name, age,city):
    self.name = name
    self.city = city
    self.age = age

   def display_profil(self):
     print(self.name, self.age, self.city)

# %%
s1 = Student("Manoj", 22, "Haryana")

# %%
s1.display_profil()
# Out:
# Manoj 22 Haryana

# %% [markdown]
# # Mini-Case-study

# %%
# A bank wants ato build a simple sysytem to manage customer accounts using Object- Oriented Programming

# Create a class named Bankaccount with the following requirements:

# requirements
# The class should have a constructor (__init__) that accepts:

# Account holder's name(holder)

# Initial account balance (balance)

# Create a method named deposit(amount) that adds the goven amount to the account balance.
# Create a methodnamed withdraw(amount) that:

# Deducts the given amount from the balance if suffiecient funds are available:

# Otherwises, displays the message:
# Insufficent balance
# Create a method named show_balance() that displays the current account balance.

# %%
class BankAccount:

  def __init__(self, holder, balance):
    self.holder = holder
    self.balance = balance


  def deposit(self, amount):
    self.balance += amount

  def withdraw(self, amount):
    if self.balance >= amount:
      self.balance -= amount
    else:
      print("Insufficent balance")

  def show_balance(self):
    print(self.balance)

# %%
bank_acc1 = BankAccount("Raj", 100000)
print(bank_acc1.holder, bank_acc1.balance)
# Out:
# Raj 100000

# %%
bank_acc1.show_balance()
# Out:
# 100000

# %%
bank_acc1.deposit(10000)
bank_acc1.show_balance()
# Out:
# 110000

# %%
bank_acc1.withdraw(20000)
bank_acc1.show_balance()
# Out:
# 90000

# %%
bank_acc1.show_balance()
# Out:
# 90000

# %%
bank_acc1.withdraw(100000)
# Out:
# Insufficent balance

# %%
# QUIZ

# %%
class Student:
  pass

s = Student()

print(type(s))
# Out:
# <class '__main__.Student'>

# %%
class Student:
  pass

s1 = Student()
s2 = Student()


print(s1 == s2)
# Out:
# False
