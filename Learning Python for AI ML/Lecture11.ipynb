# %%
# print the elements of the list in reverse order

a = [4, 6, 7, 2 , 1]
n = len(a)
for i  in range(n):
    print(a[n-1-i])
# Out:
# 1
# 2
# 7
# 6
# 4

# %%
numbers =[1, 2, 3, 4]
for i in range (len(numbers)):
    numbers[i] = numbers[i] + i

print(numbers)
# Out:
# [1, 3, 5, 7]

# %%
marks = [65, 75, 85]
total =0
for m in marks:
    if m >= 70:
        total += m  # adds 75, 85

print(total)
# Out:
# 160

# %%
nums = [2, 4, 5]
nums[0] = nums[2]
nums[2] =nums[1]
print(nums)
# Out:
# [5, 4, 4]

# %%
names = ["Aditya", "Neha", "Raj"]
longest = names[0] 
for name in names:
    if len(name) > len(longest):
        longest  = name

print(name)
# Out:
# Raj

# %%
names = ["Amit", "Neha", "Aditya"]
longest = names[0] 
for name in names:
    if len(name) > len(longest):
        longest  = name

print(name)
# Out:
# Aditya

# %%
data = [10, 20, 30]
for i in range(len(data)):
    data[i] = data[i]  + 10

print(max(data))
print(min(data))
# Out:
# 40
# 20

# %%
values = [5, 10, 15, 20]
total =0
for i in range(len(values)):
    if i%2 == 0:  # caluate only indexes in which elements 5 and  15
        total += values[i]

print(total)
# Out:
# 20

# %% [markdown]
#                          LIST SLICING

# %%
nos = [5,7,8,9,4,6,1,2,3]
print(nos)
# Out:
# [5, 7, 8, 9, 4, 6, 1, 2, 3]

# %%
print(nos[1:4]) # it prints 1 to 3 elements
# Out:
# [7, 8, 9]

# %%
print(nos[2:5])
# Out:
# [8, 9, 4]

# %%
print(nos[:4])
# Out:
# [5, 7, 8, 9]

# %%
print(nos[0:4])
# Out:
# [5, 7, 8, 9]

# %%
print(nos[1:])
# Out:
# [7, 8, 9, 4, 6, 1, 2, 3]

# %%
print(nos[:])
# Out:
# [5, 7, 8, 9, 4, 6, 1, 2, 3]

# %%
print(nos)
# Out:
# [5, 7, 8, 9, 4, 6, 1, 2, 3]

# %%
print(nos[1:5:2])
# Out:
# [7, 9]

# %%
print(nos[ : : 2])
# Out:
# [5, 8, 4, 1, 3]

# %% [markdown]
#                        STRINGS

# %%
a = "24"
type(a)
# Out:
# str

# %%
#empty stings

s = ""
type(s)
print(s)
len(s)
# Out:
# 0

# %%
len("Kaushal")
# Out:
# 7

# %%
name = "KAUSHAL"
print(name[0])
print(name[1])
print(name[-1])
# Out:
# K
# A
# L

# %%
# write the given string in reverse order
n = len(name)
for  i in range(n):
    print(name[n-1-i], end = "")
# Out:
# LAHSUAK

# %%
print(name[: : -1])
# Out:
# LAHSUAK

# %%
for i in range(n):
    print(name[i])
# Out:
# K
# A
# U
# S
# H
# A
# L

# %%
4 + 6
# Out:
# 10

# %%
"4" + "6"  # string concatenation
# Out:
# '46'

# %%
"Kaushal" + "Mehra"
# Out:
# 'KaushalMehra'

# %% [markdown]
#                               QUIZ

# %%
word = "Python"
print(word[3])  #
# Out:
# h

# %%
text = "Machine"
print(text[-2])
# Out:
# n

# %%
first  = "Kaushal"
second = " Pathankotiya"
print(first + second)
# Out:
# Kaushal Pathankotiya

# %%
print("Ai"*3)
# Out:
# AiAiAi

# %%
print("KAUSHAL")
print("-"*20)
print("Developer")
# Out:
# KAUSHAL
# --------------------
# Developer

# %%
word = "Python"
print("P" in word)
# Out:
# True

# %%
print("z" not in word)
# Out:
# True

# %%
print(word[0] + word[-1])
# Out:
# Pn

# %%
word[0] = "L"
print(word)   # strings are immutable - cannot modiify
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 word[0] = "L"
#       2 print(word)
#
# TypeError: 'str' object does not support item assignment

# %%
word = "Code"
for i in range(len(word)):
    print(i, word[i])
# Out:
# 0 C
# 1 o
# 2 d
# 3 e

# %%
word = "Code"
for i in range(len(word)):
    print("On ", i, "Index", "=", word[i])
# Out:
# On  0 Index = C
# On  1 Index = o
# On  2 Index = d
# On  3 Index = e

# %%
text = "Python"
i =0
while i < len(text):
    print(text[i])
    i += 2
# Out:
# P
# t
# o

# %%
vowel = "Kaushal"
count =0
for ch in vowel:
    if ch in "aeiouAEIOU":
        count += 1

print(count)
# Out:
# 3

# %%
text = "Programmng"
count = 0
for ch in text:
    if ch == 'm':
        count += 1

print(count)
# Out:
# 2

# %%
word ="Python"
result = ""
for ch in word:
    result = ch + result
    print(result)
# Out:
# P
# yP
# tyP
# htyP
# ohtyP
# nohtyP

# %%
domain = "Data Science"
spaces = 0
for ch in domain:
    if ch == " ":
        spaces += 1

print(spaces)
# Out:
# 1

# %%
lang = "Python"
total =0
for ch in lang:
    total += 1

print(total == len(lang))
# Out:
# True
