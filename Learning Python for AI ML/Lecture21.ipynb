# %% [markdown]
# <a href="https://colab.research.google.com/github/kaushal4445/AI-ML/blob/main/Learning%20Python%20for%20AI%20ML/Lecture21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Car:
  def __init__(self,brand):
    self.brand = brand


car1 = Car("Toyota")
car2 = car1

car2.brand = "Honda"

print(car1.brand)
# Out:
# Honda

# %%
class Car:
  def __init__(self,brand):
    self.brand = brand


car1 = Car("Toyota")
car2 = car1



print(car1.brand)
# Out:
# Toyota

# %%
class Car:
  def __init__(self,brand):
    self.brand = brand


car1 = Car("Toyota")
car2 = car1

car2.brand = "Honda"

print(car1.brand)
print(car2.brand)
# Out:
# Honda
# Honda

# %%
class Movie:
  def __init__(self, name):
    self.name = name


movie = Movie("Avatar")

print(hasattr(movie, "rating"))
# Out:
# False

# %%
class Movie:
  def __init__(self, name):
    self.name = name


movie = Movie("Avatar")

print(hasattr(movie, "Avatar"))
# Out:
# False

# %%
class Student:
  def __init__(self):
    self.age = 20

student = Student()

print(student.age + 5)
# Out:
# 25

# %%
class  Animal:
  def sound(self):
    print("Some Sound")

dog = Animal()

dog.sound()
dog.sound()
# Out:
# Some Sound
# Some Sound

# %%
class Laptop:
  def __init__(self, brand, ram):
    self.brand = brand
    self.ram = ram

laptop = Laptop("Delhi", 16)
print(laptop.brand, laptop.ram)
# Out:
# Delhi 16

# %%
class Book:
  def __init__(self, title):
    self.title = title

book1 = Book("Python")
book2 = Book("Java")

print(book1.title == book2.title)
# Out:
# False

# %%
class Student:
  def greet(self):
    return "Welcome"

student = Student()

message = student.greet()

print(message)
# Out:
# Welcome

# %%
class Bank:
  def __init__(self, balance):
    self.balance = balance

  def withdraw(self, amount):
    if amount <= self.balance:
      self.balance -= amount


account = Bank(1000)


account.withdraw(200)
account.withdraw(300)

print(account.balance)
# Out:
# 500

# %% [markdown]
# ## **Error Handling**

# %%
Print("Hello")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2055/244804411.py in <cell line: 0>()
# ----> 1 Print("Hello")
#
# NameError: name 'Print' is not defined

# %%
if 10>5:
print("Hello")
# Out:
#   File "/tmp/ipykernel_2055/350778045.py", line 2
#     print("Hello")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 1

# %%
a = 10
b = 0
print(a / b)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipykernel_2055/665098061.py in <cell line: 0>()
#       1 a = 10
#       2 b = 0
# ----> 3 print(a / b)
#
# ZeroDivisionError: division by zero

# %%
a= 0
b = 10
print(a/b)
# Out:
# 0.0

# %%
a = int(input("Enter a number: "))
b = int(input("Enter a number: "))

print(a/b)
# Out:
# Enter a number: 4
# Enter a number: 6
# 0.6666666666666666

# %%
try:
  n = int(input("Enter a number: "))
  d = int(input("Enter a number: "))
  print(n/d)
except:
  print("Invalid Input")
# Out:
# Enter a number: 100
# Enter a number: 0
# Invalid Input

# %%
try:
  a = [3, 4, 5]
  print(a[4])
except:
  print("Invalid Index")
# Out:
# Invalid Index

# %% [markdown]
# Catching Specific Errors

# %%
try:
  n = int(input("Enter a number: "))
  d = int(input("Enter a number: "))
  print(n/d)
except Exception as e:
  print(e)
# Out:
# Enter a number: 100
# Enter a number: 0
# division by zero

# %%
try:
  n = int(input("Enter a number: "))
  d = int(input("Enter a number: "))
  print(n/d)
except ZeroDivisionError:
  print("Cannot divide by zero")
except ValueError:
  print("Please enter numbers only")
# Out:
# Enter a number: kiji
# Please enter numbers only

# %%
try:
  n = int(input("Enter a number: "))
  d = int(input("Enter a number: "))
  print(n/d)
except ZeroDivisionError:
  print("Cannot divide by zero")
except ValueError:
  print("Please enter numbers only")
# Out:
# Enter a number: 100
# Enter a number: 0
# Cannot divide by zero

# %%
try:
  num = int(input("Enter a number: "))

except ValueError:
    print("Invalid Input")


else:
  print("You entered", num)
# Out:
# Enter a number: lml
# Invalid Input

# %%
try:
  num = int(input("Enter a number: "))

except ValueError:
    print("Invalid Input")


finally:
  print("YProgram finished")
# Out:
# Enter a number: 4
# YProgram finished
