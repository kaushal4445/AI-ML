# %% [markdown]
# <a href="https://colab.research.google.com/github/kaushal4445/AI-ML/blob/main/Learning%20Python%20for%20AI%20ML/Lecture22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
try:
  numbers = [5, 10, 15]

  index = 2

  print(numbers[index])

except IndexError:
  print("Wrong Index")

else:
  print("Successful")

finally:
  print("Done")

# %%
try:
  numbers = [5, 10, 15]

  index = 5

  print(numbers[index])

except IndexError:
  print("Wrong Index")

else:
  print("Successful")

finally:
  print("Done")

# %%
try:
  age = int("Twenty")
  print(age)

except ValueError:
  print("Wrong Value")


finally:
  print("Done")

# %%
try:
  student = {
      "name": "kaushal",
      "marks" : 90
  }

  print(student["age"])


except KeyError:
  print("Key Missing")

print("Program End")

# %%
try:
  student = {
      "name": "kaushal",
      "marks" : 90
  }

  print(student["marks"])


except KeyError:
  print("Key Missing")

print("Program End")

# %%
try:
  marks = 120

  if marks > 100:
    raise ValueError("Marks Invalid")

  print(marks)

except ValueError as e:
    print(e)

print("Completed")

# %%
try:
  marks = 90

  if marks > 100:
    raise ValueError("Marks Invalid")

  print(marks)

except ValueError as e:
    print(e)

print("Completed")

# %%
try:
  num = int("25")

  print(100/ num)

except ValueError:
  print("Value Error")

except ZeroDivisionError:
  print("Zero Division Error")

else:
  print("Calculation Done")

# %%
try:
  numbers = [2, 4, 6]

  print(numbers[nk])

except IndexError:
  print("Index Error")

except Exception:
  print("General Error")

finally:
  print("Done")

# %%
try:
  numbers = [2, 4, 6]

  print(numbers[5])

except IndexError:
  print("Index Error")

except Exception:
  print("General Error")

finally:
  print("Done")

# %%
try:
  value = int("50")

  print(value)

except Exception:
  print("Error")

else:
  print("Success")

finally:
  print("Done")

# %%
students = [
    {"roll no": 101,
      "name" : "Rahul",
     "age": 20,
     "course" : "Python",
     "marks": 85
     },

     {"roll no": 102,
      "name" : "Neha",
     "age": 19,
     "course" : "SQL",
     "marks": 92
     },
     {"roll no": 103,
      "name" : "Amit",
     "age": 22,
     "course" : "Python",
     "marks": 74
     },
     {"roll no": 104,
      "name" : "Priya",
     "age": 21,
     "course" : "AI",
     "marks": 96
     },
     {"roll no": 105,
      "name" : "Pyhon",
     "age": 20,
     "course" : "AI",
     "marks": 67
     },

]

# %%
student

# %%
type(students)

# %%
type(students[0])

# %%
for student in students:
  print(student)

# %%
for student in students:
  print(student["name"])

# %%
for student in students:
  print(student["marks"])

# %%
for student in students:
  print(student["age"])

# %%
for student in students:
  print(student["roll no"])

# %%
for student in students:
  print(student["course"])

# %%
total =0
for student in students:
  print(student["marks"])
  total += student["marks"]


print("Total Marks : ", total)

# %%
total =0
n = len(students)
for student in students:
  print(student["marks"])
  total += student["marks"]


print("Average Marks : ", total/n )

# %%
count =0
for student in students:
  if student["marks"] >= 40:
    count += 1

print(count)

# %%
def calc_grade(marks):
  if marks > 90:
    grade ="A"
  elif marks > 75:
    grade = "B"
  elif marks > 60:
    grade = "C"
  else:
    grade = "D"

  return grade

# %%
for student in students:
  print(student["marks"], calc_grade(student["marks"]))

# %%
def search(roll_no):
  found = False
  for student in students:
    if student["roll no"] == roll_no:
      print(student)
      return "Record Found"

  return "Not Found"

# %%
roll = int(input())

ans = search(roll)
print(ans)

# %%
students

# %%
name = input("enter a nme :")
for student in students:
  if student["name"].lower() == name.lower():
    print(student)

# %%
def find_topper(students):
  mx_marks = 0
  for student in students:
    if student["marks"] > mx_marks:
      mx_marks = student["marks"]
      topper = student


  return topper

# %%
ans = find_topper(students)
print(ans)

# %%
courses = {}
for student in students:
  if student["course"] in courses:
    courses[student["course"]] += 1
  else:
    courses[student["course"]] = 1

print(courses)

# %%
courses =[]
for student in students:
    courses.append(student["course"])

print(courses)
s = set(courses)
print(s)

# %%
class Student:
  def __init__(self, roll, name, age, course, marks):
    self.roll = roll
    self.name = name
    self.age = age
    self.course = course
    self.marks = marks

  def show_student(self):
    print(self.roll, self.name, self.age, self.course, self.marks)

# %%
s1 = Student(106, "MJ", 30, "Btech", 100)

# %%
s1.show_student()

# %%
#last 2:14

# %% [markdown]
# build Complete Student Management Menu
#
# 2. Dispplay Students
#
# 3. Search Student
#
# 4. Find Topper
#
# 5.Calculate Average
#
#
# 6.Exit

# %%
def search(roll_no):
  for student in students:
    if student["roll"] == roll_no:
      print(student)
      return "Record Found"

  return "Not Found"
def find_topper(students):
  mx_marks = 0
  topper = {}

  for student in students:
    if student["marks"] > mx_marks:
      mx_marks = student["marks"]
      topper = student
  return topper

# %%
while True:
  choice = int(input("Enter your choice: "))
  if choice == 2:
      for student in students:
          print(student)
  elif choice == 3:
      roll = int(input("Enter student Roll no: "))
      print(search(roll))
  elif choice == 4:
      print(find_topper(students))
  elif choice == 5:
      total = 0
      for student in students:
          total += student["marks"]
      print("Average:", total / len(students))
  elif choice == 6:
      print("Thank You!")
  else:
      print("Invalid Choice")
      break
