# %% [markdown]
# <a href="https://colab.research.google.com/github/kaushal4445/AI-ML/blob/main/Learning%20Python%20for%20AI%20ML/Lecture14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
fruit = {
    "Apple" : 50,
    "Banana" : 20
}

fruit["Apple"] += fruit["Banana"]
print(fruit["Apple"])
# Out:
# 70

# %%
print(fruit["Banana"])
# Out:
# 20

# %%
student = {
    "Math": 90,
    "Science" : 85,
    "English" : 95
}

highest = 0

for subject in student:
  if student[subject] > highest:
    highest = student[subject]

print(highest)
# Out:
# 95

# %%
marks = {
  "name" : "Arpita",
  "age" : 22
}

marks["age"] = marks["age"] + len(marks)
print(marks["age"])
# Out:
# 24

# %%
data = {}
data["A"] = 10
data["B"] = 20
data["C"] = 30

print(len(data))
# Out:
# 3

# %%
#Repository:     kaushal4445/AI-ML
# Branch:         main

# File path:
# Learning Python for AI ML/Lecture14.ipynb

# Commit message:
# Add Lecture14 - Dictionaries

# %%
subjects = {
    "math" : 80,
    "science": 90,
    "english" : 85
}

count =0

for  key in subjects:
  if subjects[key] >= 85:
    count += 1

print(count)
# Out:
# 2

# %%
person = {
    "name" : "Amit",
    "age" : 25
}

person.pop("age")
person["age"] = 30

print(person)
# Out:
# {'name': 'Amit', 'age': 30}

# %%
number = {
    "Math" : 90,
    "Science" : 80,
    "English" : 70
}

total =0
for subject in number:
  if number[subject] >= 80:
    total += number[subject]

print(total)
# Out:
# 170

# %%
st = {
    "math" : 95,
    "science" : 85
}

for key in st:
  print(key, st[key] // 10)
# Out:
# math 9
# science 8

# %%
dt = {
    "A" :5,
    "B" :10,
    "C" :15
}

result = 0
for key in dt:
  if dt[key] % 10 == 0:
    result += 1

print(result)
# Out:
# 1

# %%
bache = {
    "Math" : 90,
    "Science" : 80
}

bache["Total"] = 0

print(bache)
# Out:
# {'Math': 90, 'Science': 80, 'Total': 0}

# %%
for key in bache:
  if key != "Total":
    bache["Total"] += bache[key]

print(bache["Total"])
# Out:
# 170

# %% [markdown]
# # TUPLES

# %%
days = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]
days[0] = "Black DAY"

# %%
print(days)
# Out:
# ['Black DAY', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

# %%
days = days = ("Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday")
days[0] = "Pinjab band"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2849/2683246793.py in <cell line: 0>()
#       1 days = days = ("Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday")
# ----> 2 days[0] = "Pinjab band"
#
# TypeError: 'tuple' object does not support item assignment

# %%
# this means tuples canot change --> immutable

# %%
a = ("AJ", 9, 9.6, True)
print(a)
# Out:
# ('AJ', 9, 9.6, True)

# %%
type(a)
# Out:
# tuple

# %%
a[2]
# Out:
# 9.6

# %%
b = ()
print(len(b))
# Out:
# 0

# %%
type(b)
# Out:
# tuple

# %%
c = (1)
type(c)
# Out:
# int

# %%
(2 +5)
# Out:
# 7

# %%
d = (1, 2)
type(d)
# Out:
# tuple

# %%
print(a[-1])
# Out:
# True

# %%
print(a[-2])
# Out:
# 9.6

# %% [markdown]
# ### Traversing the Tuples

# %%
for elem in a:
  print(elem)
# Out:
# AJ
# 9
# 9.6
# True

# %%
n = len(a)
for i in range(n):
  print(a[i])
# Out:
# AJ
# 9
# 9.6
# True

# %%
hi  = ("p","p","r")
print("p" in hi)
# Out:
# True

# %%
# 55 minutes left

# %%
print("a" in hi)
# Out:
# False

# %%
num = (2, 4, 4,  5)
print(sum(num))
# Out:
# 15

# %%
print(num.count(4))
# Out:
# 2

# %%
num.index(4)
# Out:
# 1

# %% [markdown]
# ### Packing and Unpacking

# %%
students = ("Raj", 9.9, 24)
type(students)
# Out:
# tuple

# %%
# UNpacking
name, CGPA, age = students

# %%
print(name)
# Out:
# Raj

# %%
print(students)
# Out:
# ('Raj', 9.9, 24)

# %%
name , CGPA, age = ("Raj" , 9.9, 24)
print(name, CGPA, age)
# Out:
# Raj 9.9 24

# %%
def show():
  return 2, 3

# %%
s = show()

# %%
print(s)
# Out:
# (2, 3)

# %%
numbers = (10, 20, 30, 40)
print(numbers[2])
# Out:
# 30

# %%
fruits = ("Apple", "Banana", "Mango")
print(fruits[-2])
# Out:
# Banana

# %%
print(max(numbers))
# Out:
# 40

# %%
print(min(numbers))
# Out:
# 10

# %%
print(fruits.index("Mango"))
# Out:
# 2

# %%
colors = ("Red", "Green", "Blue")
for color in colors:
  print(color)
# Out:
# Red
# Green
# Blue

# %%
Numbers = (5, 10, 15, 20)
total =0
for num in Numbers:
  if num % 10 == 0:
    total += num

print(total)
# Out:
# 30

# %%
fruits = ("Apple", "Banana", "Mango")
for i in range(len(fruits)):
  if i % 2 == 0:
    print(fruits[i])
# Out:
# Apple
# Mango

# %%
digit = (2, 4, 6)
result =1
for dig in digit:
  result *= dig

print(result + len(digit))
# Out:
# 51

# %%
digit = (2, 4, 6)
result =0
for dig in digit:
  result *= dig

print(result + len(digit))
# Out:
# 3

# %%
people = ("Rahul", 85, 90, 95)
name = people[0]
average = sum(people[1 : ] ) /3
print(name, average)
# Out:
# Rahul 90.0

# %%
word =  ("Python", "Java", "C++" )
count =0
for item in word:
  if len(item) > 4:
    count += 1

print(count)
# Out:
# 1
