# %%
for i in range(10, 0, -2):
    print(i)
# Out:
# 10
# 8
# 6
# 4
# 2

# %%
for i in range(5, 1, -1):
    print(i)

# %%
for i in range(3, 3):
    print(i)

# %%
for i in range(4):
    print(i + 10)
# Out:
# 10
# 11
# 12
# 13

# %%
for i in range(2):
    print("Python")
print("AI")

# %%
name = "Kaushal"
for ch in name:
    if ch == "a":
        print(ch)
# Out:
# a
# a

# %%
name = "Kaushal"
for ch in name:
    if ch != "a":
        print(ch)
# Out:
# K
# u
# s
# h
# l

# %% [markdown]
#    WHILE LOOP

# %%
# three elements
# 1. initialization
# 2. condition
# 3. updation

# %%
i =1
while i < 6:
    print(i)
    i = i+1

# %%
i =1
while i < 8:
    print("Hi")
    i = i+1
# Out:
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi

# %%
i = 7
while i >= 1:
    print(i, "Hi")
    i = i-1

# %%
i =0 
while i < 11:
    print(i)
    i += 2

# %%
i =0 
while i <= 10:
    if i % 2 == 0:
    print(i)
    i += 1

# %%
i =1 
while i < 9:
    print(i)
    i += 2

# %%
i =0 
while i <= 9:
    if i % 2 != 0:
     print(i)
    i +=  1
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
sum =0
for i in range(1, 11):
    sum += i
    print(sum)
# Out:
# 1
# 3
# 6
# 10
# 15
# 21
# 28
# 36
# 45
# 55

# %%
sum =0
i =1
while i <= 10:
    sum += i
    i += 1
    print(sum)
# Out:
# 1
# 3
# 6
# 10
# 15
# 21
# 28
# 36
# 45
# 55

# %%
for i in range(1, 11 , 1):
    print("5 *", i , "=", 5*i )
# Out:
# 5 * 1 = 5
# 5 * 2 = 10
# 5 * 3 = 15
# 5 * 4 = 20
# 5 * 5 = 25
# 5 * 6 = 30
# 5 * 7 = 35
# 5 * 8 = 40
# 5 * 9 = 45
# 5 * 10 = 50

# %%
n = 5
i =1
while i <= 10:
    print(n,"*", i,"=",n*i)
    i += 1
# Out:
# 5 * 1 = 5
# 5 * 2 = 10
# 5 * 3 = 15
# 5 * 4 = 20
# 5 * 5 = 25
# 5 * 6 = 30
# 5 * 7 = 35
# 5 * 8 = 40
# 5 * 9 = 45
# 5 * 10 = 50

# %%
i =1
while i <= 10:
    print("5 *", i , "=", 5*i )
    i += 1
# Out:
# 5 * 1 = 5
# 5 * 2 = 10
# 5 * 3 = 15
# 5 * 4 = 20
# 5 * 5 = 25
# 5 * 6 = 30
# 5 * 7 = 35
# 5 * 8 = 40
# 5 * 9 = 45
# 5 * 10 = 50
