# %% [markdown]
#                        LIST

# %%
marks= [90, 80, 70, 60, 50]
print(marks)
# Out:
# [90, 80, 70, 60, 50]

# %%
a = [45, "KAUSHAL", 9.0, True]
print(a)
# Out:
# [45, 'KAUSHAL', 9.0, True]

# %%
type(a)
# Out:
# list

# %%
type(marks)
# Out:
# list

# %%
# empty list

students = []
print(students)
# Out:
# []

# %% [markdown]
#                          Indexing

# %%
marks[0]
# Out:
# 90

# %%
marks[3]
# Out:
# 60

# %%
marks[4]
# Out:
# 50

# %%
n = len(marks)
print(n)
# Out:
# 5

# %%
marks[n-1]
# Out:
# 50

# %%
marks[n-2]
# Out:
# 60

# %%
marks[-1]
# Out:
# 50

# %%
marks[-2]
# Out:
# 60

# %%
marks[2] = 100

# %%
print(marks)
# Out:
# [90, 80, 100, 60, 50]

# %% [markdown]
#      Iterating over a list

# %%
n = len(marks)
print(n)
# Out:
# 5

# %%
for i in range(n):
    print(marks[i])
# Out:
# 90
# 80
# 100
# 60
# 50

# %%
for elment in marks:
    print(elment)
# Out:
# 90
# 80
# 100
# 60
# 50

# %%
Marks = [90, 86 , 97, 83, 70]
print(Marks)
# Out:
# [90, 86, 97, 83, 70]

# %%
N = len(Marks)
print(N)
# Out:
# 5

# %%
#write a code to print the elements present at even indexes

N = len(Marks)
for i in range(N):
    if i % 2 == 0:
        print(Marks[i])
# Out:
# 90
# 97
# 70

# %%
# Write a code to pront all the even elementsN = len(Marks)
for i in range(N):
    if Marks[i] % 2 == 0:
        print(Marks[i])
# Out:
# 90
# 86
# 70

# %%
print(max(Marks))
# Out:
# 97

# %%
print(min(Marks))
# Out:
# 70

# %%
# write a code to find the sum of all the elements of the list.

s =0
for elem in Marks:
    s  = s+ elem

print(s)
# Out:
# 426

# %%
sum(Marks)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 sum(Marks)
#
# TypeError: 'int' object is not callable

# %%
# write a code to find the averge of all 
n = len(Marks)
s =0
for elem in Marks:
    s  = s+ elem

print(s/n)
# Out:
# 85.2

# %%
print(sorted(Marks))
# Out:
# [70, 83, 86, 90, 97]

# %%
print(Marks)
# Out:
# [90, 86, 97, 83, 70]

# %%
Marks.sort
# Out:
# <function list.sort(*, key=None, reverse=False)>

# %%
print(Marks)
# Out:
# [90, 86, 97, 83, 70]

# %%
names = ["A", "B", "C"]
print(names[len(names)-1])
# Out:
# C

# %%
Numbers = [5, 10, 15]
Numbers[1] = Numbers[0] + Numbers[2]

print(Numbers)
del sum
print(sum(Numbers))
# Out:
# [5, 20, 15]
# 40

# %%
score = [50, 60, 70, 80]

for i in range(len(score)):
    score[i] = score[i]  + 5
    

print(score)
# Out:
# [55, 65, 75, 85]

# %%
score = [50, 60, 70, 80]

for i in range(len(score)):
    print(i, score[i])
# Out:
# 0 50
# 1 60
# 2 70
# 3 80

# %%
Score = [1, 2, 3]

for i in range(len(Score)):
    Score[i] = Score[i]*2

print(sum(Score))
# Out:
# 12
